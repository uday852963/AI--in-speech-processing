# %%
#1

import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd

y, sr = librosa.load('AIspeech.wav')
first_derivative = np.diff(y)
first_derivative /= np.max(np.abs(first_derivative))

print("Playing First Derivative Signal:")

plt.figure(figsize=(10, 5))
librosa.display.waveshow(first_derivative, sr=sr,color='orange')
plt.title('FIRST DERIVATIVE')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

ipd.Audio(first_derivative,rate=sr)
# Out:
# Playing First Derivative Signal:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#ORIGINAL 
plt.figure(figsize=(10, 5))
librosa.display.waveshow(y, sr=sr,color='orange')
plt.title('ORIGINAL')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

ipd.Audio(y,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(10, 5)) 
librosa.display.waveshow(y, sr=sr, color='orange') 
plt.title('Original') 
plt.xlabel('Time (s)')
plt.ylabel('Amplitude') 
plt.grid(True)
plt.tight_layout()
plt.show() 

print("Playing Original Signal:") 
ipd.Audio(y, rate=sr)
# Out:
# Playing Original Signal:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#2

zero_crossings = np.where(np.diff(np.sign(first_derivative)))[0]
differences = np.diff(zero_crossings)
threshold = 1000
speech_regions = differences[differences > threshold]
silence_regions = differences[differences <= threshold]

avg_length_speech = np.mean(speech_regions)
avg_length_silence = np.mean(silence_regions)

print("Average length between consecutive zero crossings in speech regions:", avg_length_speech)
print("Average length between consecutive zero crossings in silence regions:", avg_length_silence)

plt.figure(figsize=(10, 5))
plt.plot(differences, label='All regions', color='orange')
plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions', color='green')
plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions', color='green')
plt.title('Pattern of Zero Crossings')
plt.xlabel('Zero Crossing Difference Index')
plt.ylabel('Difference between Consecutive Zero Crossings')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print("Pattern of Zero Crossings:")
print("All regions:", differences)
print("Speech regions:", speech_regions)
print("Silence regions:", silence_regions)
# Out:
# C:\Users\UDAYBHASKER\Documents\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\UDAYBHASKER\Documents\Anaconda\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\UDAYBHASKER\AppData\Local\Temp\ipykernel_26796\1719723798.py:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions)), speech_regions, 'ro', label='Speech regions', color='green')
# C:\Users\UDAYBHASKER\AppData\Local\Temp\ipykernel_26796\1719723798.py:18: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(np.arange(len(speech_regions), len(speech_regions) + len(silence_regions)), silence_regions, 'bo', label='Silence regions', color='green')
# Average length between consecutive zero crossings in speech regions: nan
# Average length between consecutive zero crossings in silence regions: 2.9482200647249193
# Pattern of Zero Crossings:
# All regions: [1 2 4 ... 2 1 1]
# Speech regions: []
# Silence regions: [1 2 4 ... 2 1 1]

# %%
#3

word_files_mine = ['core.wav', 'dell.wav', 'shift.wav', 'speech.wav', 'subject.wav']
word_files_teammate = ['core_1.mp3', 'dell_1.mp3', 'shift_1.mp3', 'speech_1.mp3', 'subject_1.mp3']
words = ['core', 'dell', 'shift', 'speech', 'subject']
word_lengths_mine = []
word_lengths_teammate = []


for word_file in word_files_mine:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_mine.append(length_seconds)


for word_file in word_files_teammate:
    signal, sr = librosa.load(word_file, sr=None)
    length_seconds = len(signal) / sr
    word_lengths_teammate.append(length_seconds)

print("Lengths of the spoken words (Mine):", word_lengths_mine)
print("Lengths of the spoken words (Teammate):", word_lengths_teammate)

bar_width = 0.35
index = np.arange(len(words))
plt.figure(figsize=(12, 6))
plt.bar(index - bar_width/2, word_lengths_mine, bar_width, label='My Words', color='Green')
plt.bar(index + bar_width/2, word_lengths_teammate, bar_width, label="Teammate's Words", color='orange')
plt.xlabel('Words')
plt.ylabel('Length (seconds)')
plt.title('Comparison of Spoken Words Length')
plt.xticks(index, words)
plt.legend()
plt.grid(True)  
plt.tight_layout()  
plt.show()
# Out:
# Lengths of the spoken words (Mine): [2.944, 2.7306666666666666, 2.688, 2.944, 3.029333333333333]
# Lengths of the spoken words (Teammate): [2.76, 2.376, 2.208, 2.64, 2.52]

# %%
#4

statement, sr1 = librosa.load('Statement.wav')
question, sr2 = librosa.load('question.wav')

plt.figure(figsize=(10, 5))
librosa.display.waveshow(statement, sr=sr1, color='orange')
plt.title('Statement')
plt.xlabel('Time (s)') 
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))
librosa.display.waveshow(question, sr=sr2, color='orange')
plt.title('Question')
plt.xlabel('Time (s)') 
plt.ylabel('Amplitude')
plt.grid(True)
plt.tight_layout()
plt.show()
